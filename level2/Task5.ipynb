# %%
import  numpy as np
import seaborn as sns
arr=np.random.rand(100)
type(arr)
# Out:
# numpy.ndarray

# %%
arr
# Out:
# array([0.48783187, 0.77082184, 0.15921681, 0.13486714, 0.64644824,
#        0.73041846, 0.75363598, 0.0922172 , 0.66726782, 0.56913509,
#        0.05949458, 0.17534077, 0.83711846, 0.59649212, 0.9291417 ,
#        0.41444385, 0.51955251, 0.10725468, 0.45163905, 0.0454461 ,
#        0.68498752, 0.48714458, 0.33845218, 0.32600785, 0.24805776,
#        0.53923454, 0.89106114, 0.97987897, 0.4173135 , 0.40245137,
#        0.26728335, 0.34464561, 0.6412966 , 0.30706508, 0.13955081,
#        0.48692818, 0.57308227, 0.88355264, 0.90201563, 0.53379783,
#        0.870075  , 0.99266391, 0.59612484, 0.07121686, 0.78221353,
#        0.79098516, 0.79406284, 0.93317207, 0.2039579 , 0.6429077 ,
#        0.73699489, 0.625257  , 0.766335  , 0.96004282, 0.12216565,
#        0.47492653, 0.51750114, 0.15436441, 0.56841766, 0.98034609,
#        0.0377229 , 0.79526046, 0.0428883 , 0.07158444, 0.12034938,
#        0.76918955, 0.91030211, 0.33122094, 0.20041187, 0.73393425,
# ...

# %%
sns.boxplot(arr)
import matplotlib.pyplot as plt
plt.show()
