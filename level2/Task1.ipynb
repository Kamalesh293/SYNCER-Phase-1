# %%
import matplotlib.pyplot as plt
# %matplotlib inline

x=[1,2,3]
y=[2,4,6]
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title("Line chart")
plt.xlabel("X-Axis")
plt.ylabel("Y-Axis")
# Out:
# Text(0, 0.5, 'Y-Axis')

# %%
plt.plot(x, y ,label='Line Chart', marker='*')
